# %% [markdown]
# # Exercise {docnum}`ref-super`

# %% [markdown]
# There are many modules that offer file I/O solutions that are more convenient than that offered by the Python Standard library. In practice, you should use the best tool for the job, but the challenge of this exercise is to only make use of the functions offered in the Python Standard Library.

# %% [markdown]
# ## Question 1
#
# Write a script that can read a text file and count:
#
# - The number of characters in the text
# - The number of words
# - The number of vowels
#
# Test your script on {download}`alice_in_wonderland-lewis_carroll-chapter_5.txt<./exercise-data/alice_in_wonderland-lewis_carroll-chapter_5.txt>`, an extract from Lewis Carroll's Alice in Wonderland, where you should get something along the lines of:
#  - 11990 characters
#  - 2439 words
#  - 3440 vowels
# depending on how you define certain criteria.

# %% [markdown]
# ## Question 2
#
# Write a script that reads the data from {download}`data1.csv<./exercise-data/data1.csv>` and plots the data on a single set of axis. Create a legend using appropriate labels. You may assume (or rather infer from the heading) that the first column is the independent variable.

# %% [markdown]
# ## Question 3
#
# In this question you will write data to a file and test that file be reading it and plotting the data from that.
#
# 1. Generate data for the functions:
#     - $f(x) = x^3 + 2$
#     - $g(x) = -x^2 + 2x + 4$
#     - $h(x) = |4x - 1|$
#
#     for $-1 < x < 1$, and save the data to a file. Don't forget to include a header.
# 2. Read in your data and plot it. You can double check that everything is working by comparing this plot to using your data directly.

# %% [markdown]
# ## Question 4
#
# Write a script that reads the data from {download}`data2.txt<./exercise-data/data2.txt>` and outputs it in a more readable format:
# - Round each figure to 2 decimal places
# - Make sure each column is aligned with at least a 4 space gap between them
# - Make sure the decimal points of the numbers are also aligned
#
# **Hint:** Reading on {doc}`../00-basics/08-string-formatting` will help.
