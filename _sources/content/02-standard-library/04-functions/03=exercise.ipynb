# %% [markdown]
# # Exercise {docnum}`ref-super`

# %% [markdown]
# ## Question 1
#
# Re-purpose your solutions to {doc}`../02-if-statements/06=exercise`
#
# 1. **Question 4** - roots of a quadratic equation
# 2. **Question 5** - third person singular verb
#
# into functions. Turn the inputs into arguments, and instead of printing outputs, return them.
