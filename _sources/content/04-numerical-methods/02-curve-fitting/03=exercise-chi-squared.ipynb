# %% [markdown]
# # Exercise {docnum}`ref`

# %% [markdown]
# ## Question 1

# %% [markdown]
# Using pen-and-paper, reproduce the results from Equations {eq}`chisqr:a0`, {eq}`chisqr:a1`, {eq}`chisqr:u_a0` and {eq}`chisqr:u_a1` yourself.

# %% [markdown]
# ## Question 2

# %% [markdown]
# Write a program to calculate the constants $a_0$ and $a_1$ with uncertainties for the functional relation
#
# $$
# y = a_0 + a_1 x
# $$
#
# using $chi^2$ minimization from a set of $x_i$, $y_i$ and $u(y_i) = \sigma_i$ data points.
#
# Test your program by reading the data in {download}`./exercise-data/data_chisqr_01.txt`.
#
# **Answers:**
# - $a_0 = 2.8(4.6)$
# - $a_1 = 17.13(0.57)$)
