# %% [markdown]
# # Exercise {docnum}`ref`

# %% [markdown]
# ## Question 1

# %% [markdown]
# This question will involve completing the worked example for yourself. I am working on the phrasing to make it more question-like, but you may get started by following the introductory text of the worked example (no peeking at the code...)

# %% [markdown]
# ## Question 2

# %% [markdown]
# Follow-up questions, work-in-progress.
